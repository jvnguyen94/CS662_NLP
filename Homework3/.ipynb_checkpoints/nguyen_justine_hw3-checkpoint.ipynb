# %% [markdown]
# # Homework 3: RNNs
#
# ### Justine Nguyen
# In this assignment, you will use PyTorch and RNNs to solve two NLP problems:
#
# 1. Language identification
# 2. Language modeling
#
# In the first, you will train a classifier to distinguish between English and Spanish sentences, and will essentially be creating a working version of the classifier demonstrated at the end of the PyTorch walkthrough from week 3's lecture. In the second you will train a neural language model to generate new British place names. For the second part, you will find Chapter 17 of the Goldberg text to be a useful reference.
#
# **Note:** The networks that you will be training in this assignment are relatively simple, and the amounts of data are relatively small. That said, _**they will take time to train**_. On my laptop, the various networks take on the order of ≈5 minutes to train. Make sure not to wait until the last minute to do this assignment, as you will need to do a fair bit of experimentation and tinkering, and you won't want to find yourself running out of time.

# %% [markdown]
# ## Part 0: Setup
#
# In addition to Jupyter and `nose`, you will need to have `pytorch`, `numpy`, `pandas`, and Scikit-Learn installed for this assignment. As in HW2, most of your actual coding will take place in the `hw3_utils` module, and we will use unit tests to verify that things are working appropriately.

# %%
import nose
import torch
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
from importlib import reload

# %% [markdown]
# One other important thing to do is to set the random number generation seed. This will ensure deterministic results: each time you re-run the notebook, you should get the same random numbers. This is vital for ensuring reproducible results.

# %%
np.random.seed(42);
torch.manual_seed(42);

# %% [markdown]
# As before, let's check and see what versions of the libraries you've got installed:

# %%
print("My library versions:")
print(f"PyTorch: {torch.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"Numpy: {np.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"nose: {nose.__version__}")
print(f"sklearn: {sklearn.__version__}")
# Out:
# My library versions:
# PyTorch: 1.3.1
# Pandas: 1.2.1
# Numpy: 1.19.2
# matplotlib: 3.3.2
# nose: 1.3.7
# sklearn: 0.23.2

# %% [markdown]
# And we can run our tests as before:

# %%
! nosetests tests/test_environment.py
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ## Part 1: Preprocessing
#
# ### Vocabulary construction
#
# As in the last part of HW2, we will be representing our input as numeric vectors. As such, we need a way to map tokens (characters, in the case of this assignment) to numeric indices. `hw3_utils.vocab` will contain functions to do this sort of transformation. The first such function will be `build_vocab`, and will take as input a corpus of sentences and as output produce mapping dictionaries. `vocab` includes special `BOS_SYM` and `EOS_SYM` symbols, to represent the beginning and end of string, respectively- make sure that the vocabularies that your implementation builds includes these characters.
#
# * **Deliverable 1.1:** Complete the `vocab.build_vocab()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_1_char_vocab`
#
# _Hint_: Remember that you can split a string into its sequence of characters using the `list` function. For _this_ assignment, you may ignore issues of Unicode decomposition and normalization, but in "real life" you would absolutely need to worry about such things!

# %%
from hw3_utils import vocab
reload(vocab);

# %%
tiny_corpus = ["This is a sentence.", "This is another sentence.", "Here is a third."]
c2i, i2c = vocab.build_vocab(tiny_corpus)

# %%
"T" == i2c[c2i["T"]]
# Out:
# True

# %% [markdown]
# **Tests for vocab.build_vocab()**

# %%
# !nosetests tests/test_vocab.py:test_d1_1_char_vocab
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %% [markdown]
# ### Sentence representation
#
# In addition to a character inventory, we'll need a way to convert a sentence into a list of indicies. Ordinarily, one would need to worry about how to handle missing vocabulary entries (i.e., OOV words or symbols); _for this assignment_, we are ignoring this problem.
#
# * **Deliverable 1.2:** Complete the `vocab.sentence_to_vector()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_2_sentence_vector`

# %%
reload(vocab);

# %%
s = "This is a sentence."
s_vec = vocab.sentence_to_vector(s, c2i)
print(s_vec)
# Out:
# [2, 4, 14, 15, 6, 14, 15, 6, 9, 6, 15, 11, 3, 1, 11, 3, 7, 11, 8]

# %%
[i2c[c] for c in s_vec]
# Out:
# ['T',
#  'h',
#  'i',
#  's',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  's',
#  'e',
#  'n',
#  't',
#  'e',
#  'n',
#  'c',
#  'e',
#  '.']

# %% [markdown]
# **Tests for vocab.sentence_to_vector()**

# %%
# !nosetests tests/test_vocab.py:test_d1_2_sentence_vector
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %% [markdown]
# PyTorch wants its input as `torch.Tensor` objects, not as Python `list`s, so we'll need to write one more short function to do that conversion. We'll want our tensors to be of size $(1,n)$, where $n$ is the length of the sentence in characters.
#
# * **Deliverable 1.3:** Complete the `sentence_to_tensor()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_3_sentence_tensor`

# %%
reload(vocab);

# %%
s = "This is a sentence."

## n of string s
print(len(list(s)))

## Convert s to tensor
s_tens = vocab.sentence_to_tensor(s, c2i)

print(s_tens)

## n of Tensor
print(s_tens.size())
# Out:
# 19
# tensor([[ 2,  4, 14, 15,  6, 14, 15,  6,  9,  6, 15, 11,  3,  1, 11,  3,  7, 11,
#           8]])
# torch.Size([1, 19])

# %%
s_tens.shape[0]
s_tens.shape[1]
print(s_tens.type)
# Out:
# <built-in method type of Tensor object at 0x7fc8e3cc7f50>

# %% [markdown]
# **Tests for vocab.sentence_to_tensor()**

# %%
# !nosetests tests/test_vocab.py:test_d1_3_sentence_tensor
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ### Label lookup table
#
# Just as we need to be able to represent characters as indices, we also need to be able to map _labels_ to indicies. The logic for this is very similar to what we did before for characters, but without the tokenization step.
#
# * **Deliverable 1.4:** Complete the `vocab.build_label_vocab()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_4_label_vocab`

# %%
reload(vocab);

# %%
labels = ["eng","eng","spa","eng","deu"]
l2i, i2l = vocab.build_label_vocab(labels)

# %%
l2i['spa']
# Out:
# 2

# %%
i2l[2]
# Out:
# 'spa'

# %%
[l2i[l] for l in labels]
# Out:
# [1, 1, 2, 1, 0]

# %% [markdown]
# **Tests for vocab.build_label_vocab()**

# %%
# !nosetests tests/test_vocab.py:test_d1_4_label_vocab
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %% [markdown]
# ## Part 2: Language identification
#
# Language identification is often one of the first steps of an NLP pipeline, and is a foundational task in NLP. _[Automatic Language Identification in Texts: A Survey](https://arxiv.org/pdf/1804.08186.pdf)_, by Jauhiainen et al., gives an excellent overview of the task and its rich history in our field, and I would _strongly_ recommend taking a few minutes to read it before beginning this part of the assignment.
#
# Formally, we can craft language ID as a classification problem, given text sample $x$ and language $l \in L$, we want to find:
#
# $$ \operatorname*{argmax}_{l} P(l | x ) $$
#
# This can be done in a variety of ways. One common (and well-performing) technique is to use trigram character frequencies, or other character-level features (writing system, etc.); some approaches rely on or incorporate word-level features. The difficulty of the task depends on a number of factors:
#
# * How much training data one has from each language of interest (often an issue)
# * How similar the languages are to one another (Spanish and Italian are more difficult to differentiate than are English and Arabic)
# * How much ["code-switching"](https://en.wikipedia.org/wiki/Code-switching) is present in the language of interest
#
# The last point is a major one: many texts of interest (tweets, etc.) contain a mix of languages, which can cause trouble both at the time of _training_ a language identification system as well as at the time of _inference_ (i.e., when you're actually trying to _use_ your system). The problem can be compounded by mixed writing systems: due to limitations of text-entry systems, users of some non-Latin scripts often will often write e.g. Arabic using English orthography. Names of places, brands, individuals, etc. can also cause script-level code switching. Fortunately, for this assignment, you will not need to worry about this issue.
#
# We will be using [data](https://tatoeba.org/eng/downloads) from [Tatoeba](https://tatoeba.org), an online crowd-sourced language learning platform. Users collaboratively develop parallel corpora of sentences in a wide variety of languages. For this assignment, I have prepared two data sets based on Tatoeba's data:
#
# * [sentences_bilingual.csv](./data/sentences_bilingual.csv): 10,000 random English and 10,000 random Spanish sentences
# * [sentences_multilingual.csv](./data/sentences_multilingual.csv): 10,000 random sentences from each of English, Spanish, German, Italian, and French

# %% [markdown]
# ## Getting Started
#
# We'll begin with the bilingual (english/spanish) data:

# %%
bi_text = pd.read_csv("data/sentences_bilingual.csv")
bi_text.head()
# Out:
#         id lang                                           sentence
# 0  6733426  eng                Tom wasn't able to change anything.
# 1   256835  eng      I saw the sights of Kyoto during my vacation.
# 2  1404674  eng  And where are the aliens, the flying saucers, ...
# 3  4833334  eng      Is the water in the Black Sea actually black?
# 4  7241028  eng         I know a lot of people who don't eat meat.

# %% [markdown]
# Step 1 is _always_ to look at your data. Verify how many entries we have, and of what languages:

# %%
print(f"Total entries: {len(bi_text)}")
# Out:
# Total entries: 20000

# %%
bi_text.groupby('lang').count()
# Out:
#          id  sentence
# lang
# eng   10000     10000
# spa   10000     10000

# %% [markdown]
# Now, build a character inventory/vocabulary for our data:

# %%
c2i, i2c = vocab.build_vocab(bi_text.sentence.values)
l2i, i2l = vocab.build_label_vocab(bi_text.lang.values)

# %% [markdown]
# And now let's make a 80/10/20 training-validation-test split:

# %%
from sklearn.model_selection import train_test_split
bi_text_train, bi_text_test = train_test_split(bi_text, test_size=0.3)
bi_text_test, bi_text_valid = train_test_split(bi_text_test, test_size=0.3)

# %% [markdown]
# What is the resulting class distribution?

# %%
bi_text_train.groupby('lang').count()
# Out:
#         id  sentence
# lang
# eng   6983      6983
# spa   7017      7017

# %%
bi_text_test.groupby('lang').count()
# Out:
#         id  sentence
# lang
# eng   2113      2113
# spa   2087      2087

# %% [markdown]
# That's close enough to equal to be usable!

# %% [markdown]
# ## Building a model

# %% [markdown]
# For this part of the assignment, I have done much of the work for you, and have provided a skeleton class with completed initialization functions.
#
# * **Deliverable 2.1:** Following the MLP example in the PyTorch walkthrough from Week 3, complete the `forward()` method in the `nn.Module` that is started for you in `hw3_utils.lang_id`.
# * **Test:** `nosetests tests/test_lang_id.py:test_d2_1_forward`
#
#
#
# _Note_: typically, PyTorch networks are trained using minibatch training (see Goldberg 5.2.8); for the sake of keeping this assignment simple, we will not be using the standard PyTorch batching behaviors. Instead, we will be batching "manually"- calling `.backward()` and updating our parameters after a configurable interval. This will make training take a little bit longer, but will make _your_ code simpler. As such, the shape of the input will be slightly different than PyTorch expects by default. You may need to experiment a bit!
#
# Also note that this is a "many-to-one" RNN architecture. Out of the box, `nn.LSTM` is set up for _many-to-many_ architectures where the input and output are synchronized- in other words, if you feed five time points _in_ to the LSTM (i.e., providing a $(1,5)$ input), you'll get a $(1,5)$ _output_ back. Since we only care about the _last_ timepoint's output for our classification problem, at some point you'll need to extract that value.

# %%
from hw3_utils import lang_id

# %% [markdown]
# Here, I am initializing the model with 10 embedding dimensions, 20 hidden dimensions, a single LSTM layer, and two output classes (_`eng`_ and _`spa`_):

# %%
reload(lang_id);

li = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=10,
    hidden_dims=20,
    lstm_layers=1,
    output_class_n=2
)

# %%
test = li(vocab.sentence_to_tensor("this is a sentence", c2i))
li(vocab.sentence_to_tensor("this is a sentence", c2i))
# Out:
# tensor([-0.7325, -0.6553], grad_fn=<SelectBackward>)

# %%
li(vocab.sentence_to_tensor("this is a sentence", c2i)).shape
# Out:
# torch.Size([2])

# %% [markdown]
# **Tests for test_lan_id foward() for LangID class**

# %%
# !nosetests tests/test_lang_id.py:test_d2_1_forward
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.119s
#
# OK

# %% [markdown]
# **Tip**: I recommend building up the `forward()` method one layer at a time, at each step of the way verifying that the output you are seeing is what you expect.
#
# That output is the raw log-probabilities associated with each class. This is not especially user-friendly, and makes evaluation a bit more difficult than we might care for.
#
# * **Deliverable 2.2:** Implement the `predict_one()` function in `hw3_utils.lang_id`.
# * **Test:** `nosetests tests/test_lang_id.py:test_d2_2_predict_one`

# %%
reload(lang_id);

# %%
lang_id.predict_one(li, "this is a sentence", c2i, i2l)
# Out:
# 'spa'

# %%
## EDA looking looking at the difference between max() vs argmax()
test
print(test)
## grabbing the highest score
print(torch.max(test))
## grabbing index of the highest score
print(torch.argmax(test))
# Out:
# tensor([-0.8101, -0.5885], grad_fn=<SelectBackward>)
# tensor(-0.5885, grad_fn=<MaxBackward1>)
# tensor(1)

# %% [markdown]
# **Tests for test_lan_id predict_one() for LangID class**

# %%
# !nosetests tests/test_lang_id.py:test_d2_2_predict_one
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.134s
#
# OK

# %% [markdown]
# ## Training and evaluating model
#
# Next, we need to train and evaluate the model. I have provided a `train_model()` function to do the training for this model, in `hw3_utils.lang_id`. This part of the assignment features fewer automated tests, and involves a little bit more thinking and writing.

# %%
reload(lang_id);
li
# Out:
# LangID(
#   (input_lookup): Embedding(125, 10)
#   (lstm): LSTM(10, 20, batch_first=True)
#   (output): Linear(in_features=20, out_features=2, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
trained_model = lang_id.train_model(
    model=li, 
    n_epochs=1,
    training_data=bi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l,
    validation_data=bi_text_valid
)
# Out:
# 0/14000 average per-item loss: 0.007617381867021322
# 	Validation portion accuracy: 0.5022222222222222
# 1000/14000 average per-item loss: 0.6911729574203491
# 	Validation portion accuracy: 0.5022222222222222
# 2000/14000 average per-item loss: 0.6873274445533752
# 	Validation portion accuracy: 0.5994444444444444
# 3000/14000 average per-item loss: 0.6851029396057129
# 	Validation portion accuracy: 0.6033333333333334
# 4000/14000 average per-item loss: 0.6834496855735779
# 	Validation portion accuracy: 0.6466666666666666
# 5000/14000 average per-item loss: 0.6662866473197937
# 	Validation portion accuracy: 0.6688888888888889
# 6000/14000 average per-item loss: 0.6672900915145874
# 	Validation portion accuracy: 0.6855555555555556
# 7000/14000 average per-item loss: 0.6604161262512207
# 	Validation portion accuracy: 0.6894444444444444
# 8000/14000 average per-item loss: 0.6194719076156616
# 	Validation portion accuracy: 0.6988888888888889
# 9000/14000 average per-item loss: 0.5536631941795349
# 	Validation portion accuracy: 0.7361111111111112
# 10000/14000 average per-item loss: 0.4333741068840027
# 	Validation portion accuracy: 0.7783333333333333
# 11000/14000 average per-item loss: 0.4608418643474579
# 	Validation portion accuracy: 0.8116666666666666
# 12000/14000 average per-item loss: 0.3612491190433502
# 	Validation portion accuracy: 0.8611111111111112
# 13000/14000 average per-item loss: 0.3067625164985657
# 	Validation portion accuracy: 0.8922222222222222

# %%
## looking at eval_acc() by itself to see if it behaves
#lang_id.eval_acc(li, bi_text_valid, c2i, i2c, l2i, i2l)

# %%
trained_model(vocab.sentence_to_tensor("where is the library", c2i))
# Out:
# tensor([-0.7605, -0.6300], grad_fn=<SelectBackward>)

# %%
trained_model(vocab.sentence_to_tensor("donde esta la biblioteca", c2i))
# Out:
# tensor([-0.2361, -1.5593], grad_fn=<SelectBackward>)

# %% [markdown]
# Using our `predict_one()` method:

# %%
lang_id.predict_one(trained_model, "where is the library", c2i, i2l)
# Out:
# 'eng'

# %%
lang_id.predict_one(trained_model, "donde esta la biblioteca", c2i, i2l)
# Out:
# 'spa'

# %% [markdown]
# Now that we've got a trained model, it's time to evaluate its performance.
#
# * **Deliverable 2.3:** Complete the `eval_acc()` function in `hw3_utils.lang_id`. Note that PyTorch `Tensor` objects have an `argmax()` function!
# * **Test:** `nosetests tests/test_lang_id.py:test_d2_3_eval_acc`

# %%
acc, y_hat = lang_id.eval_acc(trained_model, bi_text_test, c2i, i2c, l2i, i2l)
print(f"Accuracy: {acc}")
# Out:
# Accuracy: 0.8795238095238095

# %% [markdown]
# And what if we run this on a new, _untrained_ model?

# %%
untrained = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=10,
    hidden_dims=20,
    lstm_layers=1,
    output_class_n=2
)

acc_untrained, y_hat_untrained = lang_id.eval_acc(untrained, bi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_untrained}")
# Out:
# Accuracy: 0.503095238095238

# %% [markdown]
# As expected, an untrained model gets approximately chance performance.
#
# On our trained model, we were able to achieve ≈90% accuracy on held-out test data, which is very high accuracy! Let's investigate our hyperparameter settings: how small can we make our embedding and hidden dimensions before performance suffers?
#
# * **Deliverable 2.4:** Turn both the embedding dimensions and the hidden dimensions _waaaaay_ down, to 2 each, and retrain/re-evaluate the model. Save your evaluation results to a CSV file named "deliverable_2.4.csv" with three columns: the sentence itself, the _true_ label, and the _predicted_ label. Also produce a text file named "deliverable_2.4.txt" containing the observed evaluation accuracy and an explanation of what you observe. Why is the number what it is?

# %%
## Create new architecture with low embedding dims and low hidden dims
li_low = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=2,
    hidden_dims=2,
    lstm_layers=1,
    output_class_n=2
)
## Train model based on low dimensions
trained_model_low = lang_id.train_model(
    model=li_low, 
    n_epochs=1,
    training_data=bi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l,
    validation_data=bi_text_valid
)
# Out:
# 0/14000 average per-item loss: 0.006485186982899904
# 	Validation portion accuracy: 0.49777777777777776
# 1000/14000 average per-item loss: 0.6964749097824097
# 	Validation portion accuracy: 0.49777777777777776
# 2000/14000 average per-item loss: 0.6931797862052917
# 	Validation portion accuracy: 0.49777777777777776
# 3000/14000 average per-item loss: 0.6900652050971985
# 	Validation portion accuracy: 0.5016666666666667
# 4000/14000 average per-item loss: 0.6912327408790588
# 	Validation portion accuracy: 0.5016666666666667
# 5000/14000 average per-item loss: 0.6916150450706482
# 	Validation portion accuracy: 0.5016666666666667
# 6000/14000 average per-item loss: 0.6915236115455627
# 	Validation portion accuracy: 0.5016666666666667
# 7000/14000 average per-item loss: 0.6904873847961426
# 	Validation portion accuracy: 0.5188888888888888
# 8000/14000 average per-item loss: 0.6923179030418396
# 	Validation portion accuracy: 0.5211111111111111
# 9000/14000 average per-item loss: 0.6902009844779968
# 	Validation portion accuracy: 0.6405555555555555
# 10000/14000 average per-item loss: 0.690031886100769
# 	Validation portion accuracy: 0.5272222222222223
# 11000/14000 average per-item loss: 0.6888535022735596
# 	Validation portion accuracy: 0.54
# 12000/14000 average per-item loss: 0.6901242136955261
# 	Validation portion accuracy: 0.5366666666666666
# 13000/14000 average per-item loss: 0.6889792084693909
# 	Validation portion accuracy: 0.5344444444444445

# %%
## Test with test data
acc_trained_low, y_hat_trained_low = lang_id.eval_acc(trained_model_low, bi_text_test, c2i, i2c, l2i, i2l)

## Print test accuracy
print(f"Accuracy: {acc_trained_low}")
# Out:
# Accuracy: 0.53

# %%
## test - sentence
bi_text_test_s = bi_text_test['sentence'].to_list()
## test - labels
bi_text_test_lab = bi_text_test['lang'].to_list()
## test - predicted labels
bi_text_test_pred = []

## get indiv pred for test sentence
for ii in bi_text_test_s:
    bi_text_test_pred.append(lang_id.predict_one(trained_model_low, ii, c2i, i2l))
    
## Combine all into df    
test_train_low_dim = pd.DataFrame(
    {'sentence': bi_text_test_s,
     'true_label': bi_text_test_lab,
     'pred_label': bi_text_test_pred
    })

# %%
## look at the df
#print(test_train_low_dim.head)

## Write out devlierable df
#test_train_low_dim.to_csv('deliverable_2.4.csv', index=False)

## Get the confusion matrix for the predictions.
from sklearn.metrics import classification_report, confusion_matrix
cm_test = confusion_matrix(bi_text_test_lab, bi_text_test_pred)
lang_id.pretty_conf_matrix(cm_test, ['eng','spa'])

# %% [markdown]
# ### Extending to multinomial classification
#
# Clearly, a simple LSTM classifier works very well for this binary classification problem, even for very low-dimensional networks. What if we try and do multi-class classification? Our model should, in theory, be adaptable to that case. How sensitive is it to our network dimensionality?

# %%
multi_text = pd.read_csv("data/sentences_multilingual.csv")
multi_text_train, multi_text_test = train_test_split(multi_text, test_size=0.2)

multi_text.groupby('lang').count()
# Out:
#          id  sentence
# lang
# deu   10000     10000
# eng   10000     10000
# fra   10000     10000
# ita   10000     10000
# spa   10000     10000

# %%
multi_text_train.groupby('lang').count()
# Out:
#         id  sentence
# lang
# deu   8005      8005
# eng   8006      8006
# fra   7995      7995
# ita   7961      7961
# spa   8033      8033

# %%
c2i, i2c = vocab.build_vocab(multi_text.sentence.values)
l2i, i2l = vocab.build_label_vocab(multi_text.lang.values)

# %%
multi_class = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=10,
    hidden_dims=20,
    lstm_layers=1,
    output_class_n=5
)

lang_id.train_model(
    model=multi_class, 
    n_epochs=1,
    training_data=multi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l#,
    #validation_data=bi_text_valid
);

print("done")
# Out:
# 0/40000 average per-item loss: 0.01400813926011324
# 1000/40000 average per-item loss: 1.625057339668274
# 2000/40000 average per-item loss: 1.604972243309021
# 3000/40000 average per-item loss: 1.5913326740264893
# 4000/40000 average per-item loss: 1.5945308208465576
# 5000/40000 average per-item loss: 1.5808072090148926
# 6000/40000 average per-item loss: 1.5703071355819702
# 7000/40000 average per-item loss: 1.5627260208129883
# 8000/40000 average per-item loss: 1.5536079406738281
# 9000/40000 average per-item loss: 1.4767307043075562
# 10000/40000 average per-item loss: 1.489600658416748
# 11000/40000 average per-item loss: 1.4247195720672607
# 12000/40000 average per-item loss: 1.3026137351989746
# 13000/40000 average per-item loss: 1.2739031314849854
# 14000/40000 average per-item loss: 1.2924237251281738
# 15000/40000 average per-item loss: 1.2643507719039917
# 16000/40000 average per-item loss: 1.2298492193222046
# 17000/40000 average per-item loss: 1.2219059467315674
# 18000/40000 average per-item loss: 1.0936999320983887
# 19000/40000 average per-item loss: 1.1200129985809326
# 20000/40000 average per-item loss: 1.1581529378890991
# 21000/40000 average per-item loss: 1.2446000576019287
# 22000/40000 average per-item loss: 1.1883015632629395
# 23000/40000 average per-item loss: 1.094294548034668
# 24000/40000 average per-item loss: 1.097609281539917
# 25000/40000 average per-item loss: 1.1035572290420532
# 26000/40000 average per-item loss: 1.0343185663223267
# 27000/40000 average per-item loss: 1.023389458656311
# 28000/40000 average per-item loss: 1.019749641418457
# 29000/40000 average per-item loss: 1.0353378057479858
# 30000/40000 average per-item loss: 1.0401849746704102
# 31000/40000 average per-item loss: 1.1552765369415283
# 32000/40000 average per-item loss: 1.0640530586242676
# 33000/40000 average per-item loss: 1.02004075050354
# 34000/40000 average per-item loss: 1.053135871887207
# 35000/40000 average per-item loss: 1.0094977617263794
# 36000/40000 average per-item loss: 0.9930659532546997
# 37000/40000 average per-item loss: 0.9405219554901123
# 38000/40000 average per-item loss: 0.9739192128181458
# 39000/40000 average per-item loss: 1.0314081907272339
# done

# %% [markdown]
# Now that it's trained, let's evaluate it as before:

# %%
acc_multi, y_hat_multi = lang_id.eval_acc(multi_class, multi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_multi}")
# Out:
# Accuracy: 0.5949

# %% [markdown]
# For 5-way classification, a single accuracy number is less useful than it is for binary classification. Scikit-Learn has some helpful classes for evaluating classifiers:

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# The `classification_report` function will give us a per-class breakdown of our performance:

# %%
y_multi = multi_text_test.lang.values
print(classification_report(y_multi, y_hat_multi))
# Out:
#               precision    recall  f1-score   support
#
#          deu       0.70      0.63      0.66      1995
#          eng       0.64      0.51      0.57      1994
#          fra       0.55      0.82      0.66      2005
#          ita       0.59      0.50      0.54      2039
#          spa       0.54      0.52      0.53      1967
#
#     accuracy                           0.59     10000
#    macro avg       0.60      0.59      0.59     10000
# weighted avg       0.60      0.59      0.59     10000

# %% [markdown]
# The `confusion_matrix` function will give us a raw confusion matrix; rows are "truth" and columns are "predictions".

# %%
cm = confusion_matrix(y_multi, y_hat_multi)
cm
# Out:
# array([[1263,  483,  215,   11,   23],
#        [ 532, 1011,  333,   79,   39],
#        [  15,   24, 1636,  139,  191],
#        [   2,   30,  373, 1014,  620],
#        [   2,   21,  433,  486, 1025]])

# %% [markdown]
# The `lang_id` module has a method to make nicer-looking matrices:

# %%
reload(lang_id);

# %% [raw]
# lang_id.pretty_conf_matrix(cm, ['deu','eng','fra','ita','spa'])

# %%
cm_per = cm/cm.astype(np.float).sum(axis=1)
cm_per = np.round(cm_per,2)
lang_id.pretty_conf_matrix(cm_per, ['deu','eng','fra','ita','spa'])

# %% [markdown]
# * **Deliverable 2.5:** Interpret these results. Why is our classifier performing better on some languages than on others? Put your analysis in a file named `deliverable_2.5.txt`.
#
# From here, the rest of this section is up to you. Experiment with different numbers of embedding & hidden dimensions, hidden LSTM layers, etc., and see how high you can get your classification accuracy. Also try training for additional epochs. Does that help?
#
# * **Deliverable 2.6:** Describe at least two additional models that you trained and evaluated, along with their overall and per-class accuracies. What seemed to help the most? Put your discussion in a file named `deliverable_2.6.txt`.

# %% [markdown]
# ### Model 1

# %%
c2i, i2c = vocab.build_vocab(multi_text.sentence.values)
l2i, i2l = vocab.build_label_vocab(multi_text.lang.values)

multi_class1 = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=50,
    hidden_dims=100,
    lstm_layers=1,
    output_class_n=5
)

lang_id.train_model(
    model=multi_class1, 
    n_epochs=1,
    training_data=multi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l,
);

print("done")
# Out:
# 0/40000 average per-item loss: 0.015096554532647133
# 1000/40000 average per-item loss: 1.5681564807891846
# 2000/40000 average per-item loss: 1.4908703565597534
# 3000/40000 average per-item loss: 1.405525803565979
# 4000/40000 average per-item loss: 1.2433135509490967
# 5000/40000 average per-item loss: 1.161186933517456
# 6000/40000 average per-item loss: 1.140071988105774
# 7000/40000 average per-item loss: 0.9675101637840271
# 8000/40000 average per-item loss: 0.9227878451347351
# 9000/40000 average per-item loss: 0.8444420695304871
# 10000/40000 average per-item loss: 0.9016638398170471
# 11000/40000 average per-item loss: 0.5783773064613342
# 12000/40000 average per-item loss: 0.6706953644752502
# 13000/40000 average per-item loss: 0.5513906478881836
# 14000/40000 average per-item loss: 0.456124871969223
# 15000/40000 average per-item loss: 0.6268103122711182
# 16000/40000 average per-item loss: 0.5026296377182007
# 17000/40000 average per-item loss: 0.6780515313148499
# 18000/40000 average per-item loss: 0.431626558303833
# 19000/40000 average per-item loss: 0.38887760043144226
# 20000/40000 average per-item loss: 0.5716974139213562
# 21000/40000 average per-item loss: 0.3968184292316437
# 22000/40000 average per-item loss: 0.3770311772823334
# 23000/40000 average per-item loss: 0.4167412221431732
# 24000/40000 average per-item loss: 0.6261965036392212
# 25000/40000 average per-item loss: 0.5427433848381042
# 26000/40000 average per-item loss: 0.5041707754135132
# 27000/40000 average per-item loss: 0.3298620581626892
# 28000/40000 average per-item loss: 0.44753497838974
# 29000/40000 average per-item loss: 0.3927409052848816
# 30000/40000 average per-item loss: 0.3197474181652069
# 31000/40000 average per-item loss: 0.40006789565086365
# 32000/40000 average per-item loss: 0.22790579497814178
# 33000/40000 average per-item loss: 0.3377140164375305
# 34000/40000 average per-item loss: 0.2779284715652466
# 35000/40000 average per-item loss: 0.2920127809047699
# 36000/40000 average per-item loss: 0.27203699946403503
# 37000/40000 average per-item loss: 0.2431107461452484
# 38000/40000 average per-item loss: 0.3062431216239929
# 39000/40000 average per-item loss: 0.2202080935239792
# done

# %%
acc_multi1, y_hat_multi1 = lang_id.eval_acc(multi_class1, multi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_multi1}")
# Out:
# Accuracy: 0.9355

# %%
print(classification_report(y_multi, y_hat_multi1))
# Out:
#               precision    recall  f1-score   support
#
#          deu       0.97      0.97      0.97      1995
#          eng       0.96      0.96      0.96      1994
#          fra       0.96      0.93      0.95      2005
#          ita       0.93      0.90      0.91      2039
#          spa       0.85      0.92      0.88      1967
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
lang_id.pretty_conf_matrix(confusion_matrix(y_multi, y_hat_multi1), ['deu','eng','fra','ita','spa'])

# %% [markdown]
# ### Model 2

# %%
c2i, i2c = vocab.build_vocab(multi_text.sentence.values)
l2i, i2l = vocab.build_label_vocab(multi_text.lang.values)

multi_class2 = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=10,
    hidden_dims=20,
    lstm_layers=5,
    output_class_n=5
)

lang_id.train_model(
    model=multi_class2, 
    n_epochs=1,
    training_data=multi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l,
);

print("done")
# Out:
# 0/40000 average per-item loss: 0.014566384255886078
# 1000/40000 average per-item loss: 1.6186459064483643
# 2000/40000 average per-item loss: 1.6106294393539429
# 3000/40000 average per-item loss: 1.6138083934783936
# 4000/40000 average per-item loss: 1.6100000143051147
# 5000/40000 average per-item loss: 1.604690670967102
# 6000/40000 average per-item loss: 1.6034138202667236
# 7000/40000 average per-item loss: 1.5867198705673218
# 8000/40000 average per-item loss: 1.5040799379348755
# 9000/40000 average per-item loss: 1.5461066961288452
# 10000/40000 average per-item loss: 1.513702392578125
# 11000/40000 average per-item loss: 1.4868273735046387
# 12000/40000 average per-item loss: 1.4621565341949463
# 13000/40000 average per-item loss: 1.4773797988891602
# 14000/40000 average per-item loss: 1.3777036666870117
# 15000/40000 average per-item loss: 1.474726676940918
# 16000/40000 average per-item loss: 1.3778187036514282
# 17000/40000 average per-item loss: 1.390049934387207
# 18000/40000 average per-item loss: 1.2546122074127197
# 19000/40000 average per-item loss: 1.3263320922851562
# 20000/40000 average per-item loss: 1.4182655811309814
# 21000/40000 average per-item loss: 1.320909857749939
# 22000/40000 average per-item loss: 1.2800397872924805
# 23000/40000 average per-item loss: 1.1851544380187988
# 24000/40000 average per-item loss: 1.1370844841003418
# 25000/40000 average per-item loss: 1.215935230255127
# 26000/40000 average per-item loss: 1.228627324104309
# 27000/40000 average per-item loss: 1.1178895235061646
# 28000/40000 average per-item loss: 1.1704624891281128
# 29000/40000 average per-item loss: 1.0899150371551514
# 30000/40000 average per-item loss: 1.1244759559631348
# 31000/40000 average per-item loss: 1.1355019807815552
# 32000/40000 average per-item loss: 1.174595594406128
# 33000/40000 average per-item loss: 1.1485097408294678
# 34000/40000 average per-item loss: 1.0906872749328613
# 35000/40000 average per-item loss: 1.1139285564422607
# 36000/40000 average per-item loss: 1.0840643644332886
# 37000/40000 average per-item loss: 1.0229520797729492
# 38000/40000 average per-item loss: 1.0717015266418457
# 39000/40000 average per-item loss: 0.9645671248435974
# done

# %%
acc_multi2, y_hat_multi2 = lang_id.eval_acc(multi_class2, multi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_multi2}")
# Out:
# Accuracy: 0.5487

# %%
print(classification_report(y_multi, y_hat_multi2))
# Out:
#               precision    recall  f1-score   support
#
#          deu       0.83      0.94      0.88      1995
#          eng       0.44      0.65      0.52      1994
#          fra       0.37      0.24      0.29      2005
#          ita       0.75      0.52      0.61      2039
#          spa       0.38      0.41      0.39      1967
#
#     accuracy                           0.55     10000
#    macro avg       0.55      0.55      0.54     10000
# weighted avg       0.55      0.55      0.54     10000

# %%
lang_id.pretty_conf_matrix(confusion_matrix(y_multi, y_hat_multi2), ['deu','eng','fra','ita','spa'])

# %% [markdown]
# ### Model 3

# %%
c2i, i2c = vocab.build_vocab(multi_text.sentence.values)
l2i, i2l = vocab.build_label_vocab(multi_text.lang.values)

multi_class3 = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=10,
    hidden_dims=20,
    lstm_layers=1,
    output_class_n=5
)

lang_id.train_model(
    model=multi_class3, 
    n_epochs=5,
    training_data=multi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l,
);

print("done")
# Out:
# 0/40000 average per-item loss: 0.017267780378460884
# 1000/40000 average per-item loss: 1.6146481037139893
# 2000/40000 average per-item loss: 1.615634560585022
# 3000/40000 average per-item loss: 1.6040900945663452
# 4000/40000 average per-item loss: 1.6024446487426758
# 5000/40000 average per-item loss: 1.585657000541687
# 6000/40000 average per-item loss: 1.576116681098938
# 7000/40000 average per-item loss: 1.5454658269882202
# 8000/40000 average per-item loss: 1.5438075065612793
# 9000/40000 average per-item loss: 1.5265809297561646
# 10000/40000 average per-item loss: 1.516176462173462
# 11000/40000 average per-item loss: 1.4687243700027466
# 12000/40000 average per-item loss: 1.3735586404800415
# 13000/40000 average per-item loss: 1.3905521631240845
# 14000/40000 average per-item loss: 1.3125298023223877
# 15000/40000 average per-item loss: 1.298490285873413
# 16000/40000 average per-item loss: 1.2072964906692505
# 17000/40000 average per-item loss: 1.191190242767334
# 18000/40000 average per-item loss: 1.0896291732788086
# 19000/40000 average per-item loss: 1.1715996265411377
# 20000/40000 average per-item loss: 1.007523775100708
# 21000/40000 average per-item loss: 1.060896396636963
# 22000/40000 average per-item loss: 1.1077587604522705
# 23000/40000 average per-item loss: 1.099411129951477
# 24000/40000 average per-item loss: 0.9507716298103333
# 25000/40000 average per-item loss: 0.9668483138084412
# 26000/40000 average per-item loss: 0.9314582943916321
# 27000/40000 average per-item loss: 0.9673742651939392
# 28000/40000 average per-item loss: 0.8943911790847778
# 29000/40000 average per-item loss: 0.8817188143730164
# 30000/40000 average per-item loss: 0.8727902770042419
# 31000/40000 average per-item loss: 0.7993772029876709
# 32000/40000 average per-item loss: 0.8554900288581848
# 33000/40000 average per-item loss: 0.7915635108947754
# 34000/40000 average per-item loss: 0.8720342516899109
# 35000/40000 average per-item loss: 0.8298336267471313
# 36000/40000 average per-item loss: 0.7458670735359192
# 37000/40000 average per-item loss: 0.9137250781059265
# 38000/40000 average per-item loss: 0.8530900478363037
# 39000/40000 average per-item loss: 0.7039501667022705
# 0/40000 average per-item loss: 0.0019529162673279643
# 1000/40000 average per-item loss: 0.7831029295921326
# 2000/40000 average per-item loss: 0.7822407484054565
# 3000/40000 average per-item loss: 0.8151659965515137
# 4000/40000 average per-item loss: 0.7528195977210999
# 5000/40000 average per-item loss: 0.6382863521575928
# 6000/40000 average per-item loss: 0.7448928952217102
# 7000/40000 average per-item loss: 0.6723096370697021
# 8000/40000 average per-item loss: 0.7211003303527832
# 9000/40000 average per-item loss: 0.6478064656257629
# 10000/40000 average per-item loss: 0.6298999190330505
# 11000/40000 average per-item loss: 0.7885894179344177
# 12000/40000 average per-item loss: 0.5546897649765015
# 13000/40000 average per-item loss: 0.5153883099555969
# 14000/40000 average per-item loss: 0.526104748249054
# 15000/40000 average per-item loss: 0.670798659324646
# 16000/40000 average per-item loss: 0.6415339112281799
# 17000/40000 average per-item loss: 0.7595919966697693
# 18000/40000 average per-item loss: 0.7355725169181824
# 19000/40000 average per-item loss: 0.5779047608375549
# 20000/40000 average per-item loss: 0.6578819155693054
# 21000/40000 average per-item loss: 0.6387161016464233
# 22000/40000 average per-item loss: 0.6127086281776428
# 23000/40000 average per-item loss: 0.5613594651222229
# 24000/40000 average per-item loss: 0.7059383392333984
# 25000/40000 average per-item loss: 0.5474035739898682
# 26000/40000 average per-item loss: 0.5341435670852661
# 27000/40000 average per-item loss: 0.7882667779922485
# 28000/40000 average per-item loss: 0.441257119178772
# 29000/40000 average per-item loss: 0.6449706554412842
# 30000/40000 average per-item loss: 0.49430012702941895
# 31000/40000 average per-item loss: 0.6391041278839111
# 32000/40000 average per-item loss: 0.6196784377098083
# 33000/40000 average per-item loss: 0.5325310826301575
# 34000/40000 average per-item loss: 0.5235551595687866
# 35000/40000 average per-item loss: 0.6285350322723389
# 36000/40000 average per-item loss: 0.5694164037704468
# 37000/40000 average per-item loss: 0.6325457692146301
# 38000/40000 average per-item loss: 0.6369096636772156
# 39000/40000 average per-item loss: 0.5174564719200134
# 0/40000 average per-item loss: 0.0010962015949189663
# 1000/40000 average per-item loss: 0.41275039315223694
# 2000/40000 average per-item loss: 0.413544625043869
# 3000/40000 average per-item loss: 0.5321257710456848
# 4000/40000 average per-item loss: 0.4198329448699951
# 5000/40000 average per-item loss: 0.6105945706367493
# 6000/40000 average per-item loss: 0.5251025557518005
# 7000/40000 average per-item loss: 0.4826336205005646
# 8000/40000 average per-item loss: 0.45579975843429565
# 9000/40000 average per-item loss: 0.4795018434524536
# 10000/40000 average per-item loss: 0.42364266514778137
# 11000/40000 average per-item loss: 0.38526028394699097
# 12000/40000 average per-item loss: 0.47291868925094604
# 13000/40000 average per-item loss: 0.42812496423721313
# 14000/40000 average per-item loss: 0.40019431710243225
# 15000/40000 average per-item loss: 0.6401067972183228
# 16000/40000 average per-item loss: 0.40545472502708435
# 17000/40000 average per-item loss: 0.5662702322006226
# 18000/40000 average per-item loss: 0.43955299258232117
# 19000/40000 average per-item loss: 0.40929561853408813
# 20000/40000 average per-item loss: 0.530231237411499
# 21000/40000 average per-item loss: 0.39179569482803345
# 22000/40000 average per-item loss: 0.4444234073162079
# 23000/40000 average per-item loss: 0.41318345069885254
# 24000/40000 average per-item loss: 0.5293800830841064
# 25000/40000 average per-item loss: 0.603805661201477
# 26000/40000 average per-item loss: 0.5009154677391052
# 27000/40000 average per-item loss: 0.3910926878452301
# 28000/40000 average per-item loss: 0.4719674587249756
# 29000/40000 average per-item loss: 0.3777543008327484
# 30000/40000 average per-item loss: 0.40996596217155457
# 31000/40000 average per-item loss: 0.3117329478263855
# 32000/40000 average per-item loss: 0.38215282559394836
# 33000/40000 average per-item loss: 0.44475510716438293
# 34000/40000 average per-item loss: 0.4641193449497223
# 35000/40000 average per-item loss: 0.3558025658130646
# 36000/40000 average per-item loss: 0.38943538069725037
# 37000/40000 average per-item loss: 0.42096060514450073
# 38000/40000 average per-item loss: 0.5849640369415283
# 39000/40000 average per-item loss: 0.4598437547683716
# 0/40000 average per-item loss: 0.0074774473905563354
# 1000/40000 average per-item loss: 0.3776961863040924
# 2000/40000 average per-item loss: 0.4043179452419281
# 3000/40000 average per-item loss: 0.4101904034614563
# 4000/40000 average per-item loss: 0.5234642624855042
# 5000/40000 average per-item loss: 0.4042419493198395
# 6000/40000 average per-item loss: 0.48289453983306885
# 7000/40000 average per-item loss: 0.3974173665046692
# 8000/40000 average per-item loss: 0.34915491938591003
# 9000/40000 average per-item loss: 0.32037025690078735
# 10000/40000 average per-item loss: 0.45410266518592834
# 11000/40000 average per-item loss: 0.32069724798202515
# 12000/40000 average per-item loss: 0.32333338260650635
# 13000/40000 average per-item loss: 0.29302725195884705
# 14000/40000 average per-item loss: 0.3510901927947998
# 15000/40000 average per-item loss: 0.42729365825653076
# 16000/40000 average per-item loss: 0.435796320438385
# 17000/40000 average per-item loss: 0.47572413086891174
# 18000/40000 average per-item loss: 0.28678885102272034
# 19000/40000 average per-item loss: 0.3384968042373657
# 20000/40000 average per-item loss: 0.39122331142425537
# 21000/40000 average per-item loss: 0.379245400428772
# 22000/40000 average per-item loss: 0.23305948078632355
# 23000/40000 average per-item loss: 0.3331781029701233
# 24000/40000 average per-item loss: 0.4270190894603729
# 25000/40000 average per-item loss: 0.24516481161117554
# 26000/40000 average per-item loss: 0.3701643645763397
# 27000/40000 average per-item loss: 0.36792704463005066
# 28000/40000 average per-item loss: 0.3119870126247406
# 29000/40000 average per-item loss: 0.19222939014434814
# 30000/40000 average per-item loss: 0.3798556923866272
# 31000/40000 average per-item loss: 0.388897180557251
# 32000/40000 average per-item loss: 0.38852202892303467
# 33000/40000 average per-item loss: 0.29951316118240356
# 34000/40000 average per-item loss: 0.3784952163696289
# 35000/40000 average per-item loss: 0.3449450433254242
# 36000/40000 average per-item loss: 0.25248605012893677
# 37000/40000 average per-item loss: 0.37430915236473083
# 38000/40000 average per-item loss: 0.2615276873111725
# 39000/40000 average per-item loss: 0.3220258355140686
# 0/40000 average per-item loss: 0.027407171204686165
# 1000/40000 average per-item loss: 0.21706420183181763
# 2000/40000 average per-item loss: 0.3510592579841614
# 3000/40000 average per-item loss: 0.5035490393638611
# 4000/40000 average per-item loss: 0.26415619254112244
# 5000/40000 average per-item loss: 0.2569104731082916
# 6000/40000 average per-item loss: 0.42635905742645264
# 7000/40000 average per-item loss: 0.2916024923324585
# 8000/40000 average per-item loss: 0.3529634177684784
# 9000/40000 average per-item loss: 0.20120111107826233
# 10000/40000 average per-item loss: 0.26271557807922363
# 11000/40000 average per-item loss: 0.14715729653835297
# 12000/40000 average per-item loss: 0.36583176255226135
# 13000/40000 average per-item loss: 0.24300915002822876
# 14000/40000 average per-item loss: 0.3987933099269867
# 15000/40000 average per-item loss: 0.2546676993370056
# 16000/40000 average per-item loss: 0.2227891981601715
# 17000/40000 average per-item loss: 0.25908613204956055
# 18000/40000 average per-item loss: 0.29017212986946106
# 19000/40000 average per-item loss: 0.25354424118995667
# 20000/40000 average per-item loss: 0.23529911041259766
# 21000/40000 average per-item loss: 0.18437156081199646
# 22000/40000 average per-item loss: 0.3728403151035309
# 23000/40000 average per-item loss: 0.23032093048095703
# 24000/40000 average per-item loss: 0.4345772862434387
# 25000/40000 average per-item loss: 0.18450361490249634
# 26000/40000 average per-item loss: 0.31741058826446533
# 27000/40000 average per-item loss: 0.27302417159080505
# 28000/40000 average per-item loss: 0.3427453637123108
# 29000/40000 average per-item loss: 0.3593674600124359
# 30000/40000 average per-item loss: 0.29475200176239014
# 31000/40000 average per-item loss: 0.1851891726255417
# 32000/40000 average per-item loss: 0.20905707776546478
# 33000/40000 average per-item loss: 0.3580869436264038
# 34000/40000 average per-item loss: 0.2283504158258438
# 35000/40000 average per-item loss: 0.2664552927017212
# 36000/40000 average per-item loss: 0.2365058958530426
# 37000/40000 average per-item loss: 0.18477612733840942
# 38000/40000 average per-item loss: 0.2509496808052063
# 39000/40000 average per-item loss: 0.281823992729187
# done

# %%
acc_multi3, y_hat_multi3 = lang_id.eval_acc(multi_class3, multi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_multi3}")
# Out:
# Accuracy: 0.9162

# %%
print(classification_report(y_multi, y_hat_multi3))
# Out:
#               precision    recall  f1-score   support
#
#          deu       0.95      0.95      0.95      1995
#          eng       0.95      0.93      0.94      1994
#          fra       0.92      0.92      0.92      2005
#          ita       0.84      0.96      0.90      2039
#          spa       0.94      0.82      0.88      1967
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000

# %%
lang_id.pretty_conf_matrix(confusion_matrix(y_multi, y_hat_multi3), ['deu','eng','fra','ita','spa'])

# %% [markdown]
# ## Part 3: Language modeling & Text Generation
#
# ### Getting Started
#
# In this part of the assignment, you will build and evaluate a simple LSTM character language model, and then _sample_ from it to generate new text mimicking the training data. The model you will build should follow the general structure outlined in Section 17.1 of the Goldberg text, and use the "teacher-forcing" training method outlined in 17.1.1.
#
# $$ p(\mathbf{w}_n | \mathbf{w}_{1:n-1}) = \operatorname*{softmax} \mathbf{o}^{(n-1)} $$
#
# $$ o = \mathbf{h} \mathbf{W}_o^T + b_o $$
#
# $$ \mathbf{h} = LSTM(\mathbf{x})$$
#
# $$ \mathbf{x}_{1:n-1} = \mathbf{E}[w_1], ... , \mathbf{E}[w_n-1] $$
#
# For this part of the assignment, we will be working with a data set of British place names located in `data/towns_clean.txt`.

# %%
corpus = [l.strip() for l in open('data/towns_clean.txt')]
c2i, i2c = vocab.build_vocab(corpus)

for t in np.random.choice(corpus, size=10):
    print(t)
# Out:
# Kirkpatrick Durham
# Cambusbarron
# Sidcot
# East Grafton
# Chalkwell
# Langridge
# Puttock's End
# Lydney
# Noon Nick
# Booth of Toft

# %% [markdown]
# Your network, once trained, will learn to recognize British place names, and will be able to make up new ones.
#
# * **Deliverable 3.1:** Implement the `__init__()`, and `forward()` functions in `hw3_utils.lm.NameGenerator`.
# * **Test:** `nosetests tests/test_lm.py:test_d3_1_setup`
#
# Once you've got these methods set up correctly, the following ought to work (in the sense of producing appropriately-sized output):

# %%
from hw3_utils import lm
reload(lm);

# %%
model = lm.NameGenerator(
    input_vocab_size=len(c2i),
    n_embedding_dims=25,
    n_hidden_dims=50,
    n_lstm_layers=1,
    output_vocab_size=len(c2i)
)

x = vocab.sentence_to_tensor("Test input", c2i, True) # make sure to pad w/ bos/eos symbols
y_hat, lstm_hidden_state = model(x, model.init_hidden())
y_hat.shape # should be 1x12x77 (1 x len("Test input")+2 x len(c2i))
# Out:
# torch.Size([1, 12, 77])

# %% [markdown]
# **Tests for test_lm setup for NameGenerator Class**

# %%
# !nosetests tests/test_lm.py:test_d3_1_setup
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.085s
#
# OK

# %% [markdown]
# Each position $i$ along the second dimension of $\hat{y}$ is the model's estimate of $p(x_{i+1} | x_{1:i})$, and is represented as a multinomial probability distribution in log-space (i.e., each of the 78 possible characters is assigned an estimated log-probability of occurring).
#
# By multiplying across (or summing across, in log-space) each of those values, we can calculate the model's estimate of the probability of an input sequence (see Jurafsky & Martin, Chapter 3 if you need refresher on how this works). As a convenience method, I have provided `lm.compute_prob`.

# %%
lm.compute_prob(model, "Test input", c2i)
# Out:
# 47.922340393066406

# %%
lm.compute_prob(model, "fdsafsadfa", c2i)
# Out:
# 47.855735778808594

# %% [markdown]
# This produces _negative log probabilities_. In this case, the model has not yet been trained and so the two sequences are given (very roughly) equivalent probabilities
#
# Note that "out of the box" `compute_prob()` does not _normalize_ the probabilities by sequence length, and as such longer sequences will have lower probabilities on average than shorter sequences, regardless of how plausible they are to the model. If you want to compare the model's estimate of the probabilities of two sequences of different lengths, you must normalize each by the appropriate sequence's length.
#
# Once the model is trained, the estimated probabilities of the two sequences above should be quite different!

# %% [markdown]
# ### Training
#
# Note that there are two ways to structure the training of this sort of model.
#
# 1. One character at a time
# 2. In a quasi batched manner
#
# The equations above describe character-at-a-time training- starting from the shortest possible prefix of our sequence $\mathbf{w}$, $\mathbf{w}_{1:1}$, and continuing up through successively longer prefixes until reaching $\mathbf{w}_{1:n-1}$, ask the model to predict the next character, accumulating loss with the negative log-likelihood criterion.
#
# In this scenario, if our input training sentence was _"hello there"_, we would perform a series of forward passes:
#
# $x_1="h"$, $y_1="e"$
#
# $x_2="he"$, $y_2="l"$
#
# $x_3="hel"$, $y_3="l"$
#
# ... and so forth, either doing a call to `backward()` after each prefix $x_i$ or waiting until the end of the sequence to do so.
#
# This way works just fine, and is more or less how we will go about sampling from the model, but it is often more efficient to do a more batched training operation. Note that in the above equations, $\mathbf{o}$ will have dimensionality of $(1, n-1, N_{classes})$- in other words, there will be one set of probability estimates for each time point that we have provided the LSTM. PyTorch's `nn.NLLLoss` class can accept input in this shape, and will automatically compute the average loss across the timepoints (and of course will do so a way that keeps the gradients around for correct backpropagation). Training this way can reduce the total number of computations that we need to do in order to train our model.
#
# In this scenario, we would perform a _single_ forward and backward pass, with input that looked like so:
#
# $x="hello\_ther"$, $y="ello\_there"$
#
# Note that PyTorch is perfectly happy either way: the various `nn.*` classes all expect to be able to be given input in this minibatched format. In the first training strategy, the "batch" size is 1; in the second, it is $n-1$ where $n$ is the length of the training example.
#
# The overall process of training this model will be very similar to how we trained the language ID classifier, so use that as a starting point and modify as needed. For starters, train with the following parameters:
#
# * Number of character embedding dimensions: 25
# * Number of LSTM hidden units: 50
# * Number of LSTM layers: 1
#
# Once your model is trained, you can save it to disk using the `torch.save()` function. This will make it available for the unit test to access.
#
# * **Deliverable 3.2:** Implement the `train()` function in `hw3_utils.lm`. Save a trained model to a file named `deliverable_3.2.mod`.
# * **Test:** `nosetests tests/test_lm.py:test_d3_2_training`

# %%
from hw3_utils import lm
reload(lm);
lm.train(model, epochs=2, training_data=corpus, c2i=c2i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-aaf8f164cca9> in <module>
#       1 from hw3_utils import lm
#       2 reload(lm);
# ----> 3 lm.train(model, epochs=2, training_data=corpus, c2i=c2i)
#
# ~/CS662_NLP/Homework3/hw3_utils/lm.py in train(model, epochs, training_data, c2i)
#      82     for i in range(epochs):
#      83
# ---> 84         x_train = training_data.sentence.values
#      85         y_train = training_data.lang.values
#      86
#
# AttributeError: 'list' object has no attribute 'sentence'

# %%
lm.compute_prob(model, "Test input", c2i)

# %%
lm.compute_prob(model, "fdsafsadfa", c2i)
# Out:
# 56.40491485595703

# %% [markdown]
# Remember, this is in log-space, so the difference here is substantial. And now let's try giving it an actual town name as input:

# %%
lm.compute_prob(model, "Wavertree", c2i)
# Out:
# 51.681156158447266

# %%
# !nosetests tests/test_lm.py:test_d3_2_training
# Out:
# F
# ======================================================================
# FAIL: test_lm.test_d3_2_training
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/nguyjust/opt/anaconda3/lib/python3.7/site-packages/nose/case.py", line 197, in runTest
#     self.test(*self.arg)
#   File "/Users/nguyjust/CS662_NLP/Homework3/tests/test_lm.py", line 41, in test_d3_2_training
#     assert_true(os.path.exists(model_fname))
# AssertionError: False is not true
# -------------------- >> begin captured logging << --------------------
# matplotlib: DEBUG: (private) matplotlib data path: /Users/nguyjust/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data
# matplotlib: DEBUG: matplotlib data path: /Users/nguyjust/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data
# matplotlib: DEBUG: CONFIGDIR=/Users/nguyjust/.matplotlib
# matplotlib: DEBUG: matplotlib version 3.3.2
# matplotlib: DEBUG: interactive is False
# matplotlib: DEBUG: platform is darwin
# matplotlib: DEBUG: loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'posix', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', 'site', 'os', 'stat', '_stat', '_collections_abc', 'posixpath', 'genericpath', 'os.path', '_sitebuiltins', '_bootlocale', '_locale', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'sphinxcontrib', 'zope', 'encodings.cp437', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'nose', 'nose.core', 'logging', 'time', 'traceback', 'linecache', 'tokenize', 'token', 'weakref', '_weakrefset', 'collections.abc', 'string', '_string', 'threading', 'atexit', 'unittest', 'unittest.result', 'unittest.util', 'unittest.case', 'difflib', 'pprint', 'unittest.suite', 'unittest.loader', 'fnmatch', 'unittest.main', 'argparse', 'gettext', 'locale', 'unittest.runner', 'unittest.signals', 'signal', 'nose.config', 'optparse', 'textwrap', 'errno', 'configparser', 'nose.util', 'inspect', 'dis', 'opcode', '_opcode', 'nose.pyversion', 'nose.plugins', 'nose.plugins.base', 'nose.plugins.manager', 'nose.failure', 'pickle', 'struct', '_struct', '_compat_pickle', '_pickle', 'pkg_resources', 'zipfile', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'pwd', 'grp', 'binascii', 'pkgutil', 'platform', 'subprocess', '_posixsubprocess', 'select', 'selectors', 'math', 'plistlib', 'datetime', '_datetime', 'xml', 'xml.parsers', 'xml.parsers.expat', 'pyexpat.errors', 'pyexpat.model', 'pyexpat', 'xml.parsers.expat.model', 'xml.parsers.expat.errors', 'email', 'email.parser', 'email.feedparser', 'email.errors', 'email._policybase', 'email.header', 'email.quoprimime', 'email.base64mime', 'base64', 'email.charset', 'email.encoders', 'quopri', 'email.utils', 'random', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'socket', '_socket', 'urllib', 'urllib.parse', 'email._parseaddr', 'calendar', 'tempfile', 'ntpath', 'pkg_resources.extern', 'pkg_resources._vendor', 'pkg_resources._vendor.appdirs', 'pkg_resources.extern.appdirs', 'pkg_resources._vendor.packaging', '__future__', 'pkg_resources._vendor.packaging.__about__', 'pkg_resources.extern.packaging', 'pkg_resources.extern.packaging.version', 'pkg_resources.extern.packaging._structures', 'pkg_resources.extern.packaging._typing', 'pkg_resources.extern.packaging.specifiers', 'pkg_resources.extern.packaging._compat', 'pkg_resources.extern.packaging.utils', 'pkg_resources.extern.packaging.requirements', 'pkg_resources._vendor.pyparsing', 'copy', 'pkg_resources.extern.pyparsing', 'pkg_resources.extern.packaging.markers', 'sysconfig', '_osx_support', '_sysconfigdata_m_darwin_darwin', 'nose.plugins.plugintest', 'multiprocessing', 'multiprocessing.context', 'multiprocessing.process', 'multiprocessing.reduction', 'array', '__mp_main__', 'nose.loader', 'nose.case', 'nose.importer', 'imp', 'nose.selector', 'nose.suite', 'nose.proxy', 'nose.result', 'nose.exc', 'nose.plugins.skip', 'nose.plugins.errorclass', 'nose.plugins.deprecated', 'nose.tools', 'nose.tools.nontrivial', 'nose.tools.trivial', 'nose.plugins.builtin', 'nose.plugins.attrib', 'nose.plugins.capture', 'nose.plugins.logcapture', 'nose.plugins.cover', 'nose.plugins.debug', 'pdb', 'cmd', 'bdb', 'code', 'codeop', 'glob', 'nose.plugins.doctests', 'doctest', 'nose.plugins.isolate', 'nose.plugins.failuredetail', 'nose.inspector', 'nose.plugins.prof', 'nose.plugins.testid', 'nose.plugins.multiprocess', 'queue', '_queue', 'nose.plugins.xunit', 'xml.sax', 'xml.sax.xmlreader', 'xml.sax.handler', 'xml.sax._exceptions', 'xml.sax.sa ...
# matplotlib: DEBUG: CACHEDIR=/Users/nguyjust/.matplotlib
# matplotlib.font_manager: DEBUG: Using fontManager instance from /Users/nguyjust/.matplotlib/fontlist-v330.json
# matplotlib.pyplot: DEBUG: Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# --------------------- >> end captured logging << ---------------------
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.087s
#
# FAILED (failures=1)

# %% [markdown]
# ### Sampling
#
# Now that we've got a language model trained, we can sample from it to generate _new_ names. Follow the general procedure outlined in Goldberg 9.5:
#
# 1. Build an initial history consisting of the `vocab.BOS_SYM` symbol
# 2. Using this history, query the language model, and predict a distribution over next characters
# 3. Sample a character from that distribution
# 4. Concatenate the selected character to make a _new_ history
# 5. Repeat from step 2 until the selected character is `vocab.EOS_SYM` or we hit a maximum length (200 characters, in this assignment).
#
# Once you've implemented sampling, you can generate hilarious and adorable new names!
#
# * **Deliverable 3.3:** Implement the `sample()` function in `hw3_utils.lm`
# * **Test:** `nosetests tests/test_lm.py:test_d3_3_sample`
#
# _Hint_: The `torch.multinomial()` function samples from a multinomial distribution stored in a `Tensor`, but _it requires real-space probabilities_, not log-space. `Tensor`s have a `.exp()` method that you may need to use.

# %%
for i in range(10):
    print(lm.sample(model, c2i, i2c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1b0e6839147d> in <module>
#       1 for i in range(10):
# ----> 2     print(lm.sample(model, c2i, i2c))
#
# NameError: name 'lm' is not defined

# %% [markdown]
# ### Improving your model
#
# These generated names should look more like names of towns than random sequences, but they are a little bit rough compared to the names in the data file. Try modifying your training process to go for additional epochs, and see how that changes your sampled sentences. Also, experiment with different model parameters. What happens if you _decrease_ number of hidden dimensions? What about _increasing_ the dimensionality? How about adding more layers to the LSTM?
#
# One useful thing to try: now that the `sample()` function is written, you might try adding some reporting code to your `train()` function: at regular intervals during training (e.g. every 1000 training examples), you could have it print out a few random towns generated from the model at its current state. This way, you can watch the model evolve over time. How many examples does it need to see before it learns that names always start with upper-case letters?
#
# * **Deliverable 3.4:** Write up a short summary of your observations and investigations into model behavior, including examples, and put it in a text file called `deliverable_3.4.txt`.
