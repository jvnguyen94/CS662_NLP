# %% [markdown]
# ## Homework 1: Getting Our Feet Wet
#
# ### CS 662: Natural Language Processing
#
# ### Justine Nguyen
#
# #### 01/09/2021

# %%
import nltk
import lxml.etree
import gzip

# %% [markdown]
# ## Part 1: Reading some data
